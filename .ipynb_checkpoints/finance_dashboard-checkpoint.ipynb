# %%
import pandas as pd
import matplotlib.pyplot as plt

#  Load dataset
df = pd.read_csv("finance.csv")
df.head()

#  Explore data
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     18 non-null     object
#  1   Category  18 non-null     object
#  2   Amount    18 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 564.0+ bytes
# None
#             Amount
# count    18.000000
# mean   2605.555556
# std    1373.476577
# min    1200.000000
# 25%    1600.000000
# 50%    2250.000000
# 75%    2950.000000
# max    5500.000000

# %%
#  Category-wise total spending (Bar chart)
category_total = df.groupby("Category")["Amount"].sum()
plt.figure(figsize=(8,5))
category_total.plot(kind="bar", color="skyblue")
plt.title("Total Spending by Category")
plt.xlabel("Category")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.show()

# %%
# Expense distribution (Pie chart)
plt.figure(figsize=(8,8))
category_total.plot(kind="pie", autopct="%1.1f%%", colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6'])
plt.title("Expense Distribution")
plt.ylabel("")
plt.show()

# %%
# Savings vs Shopping comparison (Bar chart)
comparison = df[df["Category"].isin(["Savings","Shopping"])]
pivot_data = comparison.pivot(index="Month", columns="Category", values="Amount")
pivot_data.plot(kind="bar", figsize=(8,5))
plt.title("Savings vs Shopping")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.show()

# %%
#  Category trends over months
category_month = df.pivot_table(values="Amount", index="Month", columns="Category", aggfunc="sum")
category_month.plot(figsize=(10,6), marker="o")
plt.title("Monthly Spending by Category")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.show()

# %%
print("Insights:")
print("- Savings had the highest allocation")
print("- Shopping expenses increased over time")
print("- Entertainment spending was lowest")
# Out:
# Insights:
# - Savings had the highest allocation
# - Shopping expenses increased over time
# - Entertainment spending was lowest
